# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

# %% [markdown]
# # Ejemplo 1

# %%
t = sp.symbols('t')
k = sp.symbols('k')
# Def frec y periodo fundamental
f = 1
T = 1/f
# Calcula simbolicamnete la exepresion de los coeficientes de fourier
expk = sp.integrate(-1*sp.exp(-1*sp.I*k*2*sp.pi*f*t), (t, -1/2, 0))/T + sp.integrate(sp.exp(-1*sp.I*k*2*sp.pi*f*t), (t, 0, 1/2))/T
sp.pprint(expk)
# Out:
#     ⎛⎧             -1.0⋅ⅈ⋅π⋅k                            ⎞       ⎛⎧   1.0⋅ⅈ⋅π⋅ ↪
#     ⎜⎪    ⅈ     ⅈ⋅ℯ                                      ⎟       ⎜⎪ⅈ⋅ℯ         ↪
#     ⎜⎪- ───── + ─────────────  for k > -∞ ∧ k < ∞ ∧ k ≠ 0⎟       ⎜⎪─────────── ↪
# 1.0⋅⎜⎨  2⋅π⋅k       2⋅π⋅k                                ⎟ + 1.0⋅⎜⎨   2⋅π⋅k    ↪
#     ⎜⎪                                                   ⎟       ⎜⎪            ↪
#     ⎜⎪          0.5                    otherwise         ⎟       ⎜⎪        -0. ↪
#     ⎝⎩                                                   ⎠       ⎝⎩            ↪
#
# ↪ k                                    ⎞
# ↪       ⅈ                              ⎟
# ↪ ─ - ─────  for k > -∞ ∧ k < ∞ ∧ k ≠ 0⎟
# ↪     2⋅π⋅k                            ⎟
# ↪                                      ⎟
# ↪ 5                  otherwise         ⎟
# ↪                                      ⎠

# %%
# Rango de los armonicos para los coeficientes
am = 25
armo = np.arange(-am, am+1, 1)
# Evaluacion de la expresion de los coeficientes de Fourier
coef = [complex(expk.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier
modcoef = np.abs(coef)
# Fase de los coef de fourier
fascoef = np.angle(coef)
# Grafica del modulo y fase de los coeficientes
plt.figure(figsize=(12, 6))

# Plot modulus of Fourier coefficients
plt.subplot(2, 1, 1)
plt.stem(armo, modcoef)
plt.title('Modulo de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

# Plot phase of Fourier coefficients
plt.subplot(2, 1, 2)
plt.stem(armo, fascoef)
plt.title('Fase de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Fase')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Actividad 1
# ![image.png](attachment:image.png)

# %% [markdown]
# la funcion f seria: $f(t) =  1 \text{ si } |x-kT|< |p/2| $ con  k  $\Z$

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp
p = 1 # Ancho del escalon
t=sp.symbols('t')
k=sp.symbols('k')
T = 5 #Periodo
f = 1/T
# Calucle simbolicamente la expresion del coeficiente de fourier
expk = sp.integrate(sp.exp(-1*sp.I*k*2*sp.pi*f*t), (t, -p/2, p/2))/T
sp.pprint(expk)
# Out:
# ⎧         0.2⋅ⅈ⋅π⋅k          -0.2⋅ⅈ⋅π⋅k
# ⎪  2.5⋅ⅈ⋅ℯ            2.5⋅ⅈ⋅ℯ
# ⎪- ──────────────── + ─────────────────  for k > -∞ ∧ k < ∞ ∧ k ≠ 0
# ⎨        π⋅k                 π⋅k
# ⎪
# ⎪                 1.0                            otherwise
# ⎩
# ───────────────────────────────────────────────────────────────────
#                                  5

# %% [markdown]
# $\frac{\begin{cases} - \frac{2.5 i e^{0.2 i \pi k}}{\pi k} + \frac{2.5 i e^{- 0.2 i \pi k}}{\pi k} & \text{for}\: k > -\infty \wedge k < \infty \wedge k \neq 0 \\1.0 & \text{otherwise} \end{cases}}{5}$

# %%
# Rango de los armonicos para los coeficientes
am = 25
armo = np.arange(-am, am+1, 1)
# Evaluacion de la expresion de los coeficientes de Fourier
coef = [complex(expk.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier
modcoef = np.abs(coef)
# Fase de los coef de fourier
fascoef = np.angle(coef)

# Grafica del modulo y fase de los coeficientes
plt.figure(figsize=(12, 6))

# Plot modulus of Fourier coefficients
plt.subplot(2, 1, 1)
plt.stem(armo, modcoef)
plt.title('Modulo de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

# Plot phase of Fourier coefficients
plt.subplot(2, 1, 2)
plt.stem(armo, fascoef)
plt.title('Fase de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Fase')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## $b)$
# Graficar los coeficientes de Fourier para la señal desplazada f(t-(p/2)). ¿Cómo se modifican dichos coeficientes? Tenga en cuenta que los coeficientes están en el dominio de la frecuencia.

# %%
# Desplazo la señal en el dominio del tiempo aplicando propiedades de la serie de Fourier (multiplico por e^(-i*2*pi*k*f*p/2)
expk_2 = expk * sp.exp(-1*sp.I*k*2*sp.pi*f*(p/2))

# Evaluacion de la expresion de los coeficientes de Fourier desplazados
coef_2 = [complex(expk_2.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier desplazados
modcoef_2 = np.abs(coef_2)
# Fase de los coef de fourier desplazados
fascoef_2 = np.angle(coef_2)

# Grafica del modulo y fase de los coeficientes desplazados
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.stem(armo, modcoef_2)
plt.title('Modulo de los Coeficientes de Fourier Desplazados')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

plt.subplot(2, 1, 2)
plt.stem(armo, fascoef_2)
plt.title('Fase de los Coeficientes de Fourier Desplazados')
plt.xlabel('Armonicos')
plt.ylabel('Fase')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## $c)$
# Graficar los coeficientes de Fourier para la señal comprimida f(2t). ¿Cómo se modifican dichos coeficientes? Tenga en cuenta que los coeficientes están en el dominio de la frecuencia.

# %%
# Comprimir la señal en el dominio del tiempo aplicando propiedades de la serie de Fourier
a = 2
expk_compressed = expk * sp.exp(sp.I*k*a*2*sp.pi*f)

# Evaluacion de la expresion de los coeficientes de Fourier comprimidos
coef_compressed = [complex(expk_compressed.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier comprimidos
modcoef_compressed = np.abs(coef_compressed)
# Fase de los coef de fourier comprimidos
fascoef_compressed = np.angle(coef_compressed)

# Grafica del modulo y fase de los coeficientes comprimidos
plt.figure(figsize=(12, 6))

plt.subplot(2, 1, 1)
plt.stem(armo, modcoef_compressed)
plt.title('Modulo de los Coeficientes de Fourier Comprimidos')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

plt.subplot(2, 1, 2)
plt.stem(armo, fascoef_compressed)
plt.title('Fase de los Coeficientes de Fourier Comprimidos')
plt.xlabel('Armonicos')
plt.ylabel('Fase')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Actividad 2
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

t = sp.symbols('t')
k = sp.symbols('k')
d = sp.symbols('d') # Ancho del escalon, luego reemplazaré
T = 20
f = 1/T
w = 2*sp.pi*f
# Calculo simbolicament ela expresion del coef. de la serie de Fourier compleja con f(t)=1
expk = sp.integrate(sp.exp(-1*sp.I*k*w*t), (t, -d/2, d/2))/T
sp.pprint(expk)

# Rango de los armonicos para los coeficientes
am = 25
armo = np.arange(-am, am+1, 1)
# Out:
# ⎧          0.05⋅ⅈ⋅π⋅d⋅k           -0.05⋅ⅈ⋅π⋅d⋅k
# ⎪  10.0⋅ⅈ⋅ℯ               10.0⋅ⅈ⋅ℯ
# ⎪- ──────────────────── + ─────────────────────  for k > -∞ ∧ k < ∞ ∧ k ≠ 0
# ⎨          π⋅k                     π⋅k
# ⎪
# ⎪                      d                                 otherwise
# ⎩
# ───────────────────────────────────────────────────────────────────────────
#                                     20

# %% [markdown]
# d = 2

# %%
# Evaluacion de la expresion de los coeficientes de Fourier con d = 2
expk_2 = expk.subs(d, 2)
coef_2 = [complex(expk_2.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier
modcoef_2 = np.abs(coef_2)
# Fase de los coef de fourier
fascoef_2 = np.angle(coef_2)

# Grafica del modulo y fase de los coeficientes
plt.figure(figsize=(12, 6))
plt.suptitle('Coeficientes de Fourier con d=2')
# Plot modulus of Fourier coefficients
plt.subplot(2, 1, 1)
plt.stem(armo, modcoef_2)
plt.title('Modulo de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

# Plot phase of Fourier coefficients
plt.subplot(2, 1, 2)
plt.stem(armo, fascoef_2)
plt.title('Fase de los Coeficientes de Fourier')
plt.xlabel('Armonicos')

plt.tight_layout()
plt.show()

# %% [markdown]
# d = 4

# %%
# Evaluacion de la expresion de los coeficientes de Fourier con d = 4
expk_4 = expk.subs(d, 4)
coef_4 = [complex(expk_4.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier
modcoef_4 = np.abs(coef_4)
# Fase de los coef de fourier
fascoef_4 = np.angle(coef_4)

# Grafica del modulo y fase de los coeficientes
plt.figure(figsize=(12, 6))
plt.suptitle('Coeficientes de Fourier con d=4')
# Plot modulus of Fourier coefficients
plt.subplot(2, 1, 1)
plt.stem(armo, modcoef_4)
plt.title('Modulo de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

# Plot phase of Fourier coefficients
plt.subplot(2, 1, 2)
plt.stem(armo, fascoef_4)
plt.title('Fase de los Coeficientes de Fourier')
plt.xlabel('Armonicos')

plt.tight_layout()
plt.show()

# %% [markdown]
# d = 5

# %%
# Evaluacion de la expresion de los coeficientes de Fourier con d = 5
expk_5 = expk.subs(d, 5)
coef_5 = [complex(expk_5.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier
modcoef_5 = np.abs(coef_5)
# Fase de los coef de fourier
fascoef_5 = np.angle(coef_5)

# Grafica del modulo y fase de los coeficientes
plt.figure(figsize=(12, 6))
plt.suptitle('Coeficientes de Fourier con d=5')
# Plot modulus of Fourier coefficients
plt.subplot(2, 1, 1)
plt.stem(armo, modcoef_5)
plt.title('Modulo de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

# Plot phase of Fourier coefficients
plt.subplot(2, 1, 2)
plt.stem(armo, fascoef_5)
plt.title('Fase de los Coeficientes de Fourier')
plt.xlabel('Armonicos')

plt.tight_layout()
plt.show()

# %%
# Subplot grande comparando los 3 graficos con distintos valores de d = [2,4,5] con T=20ms fijo
plt.figure(figsize=(18, 12))
plt.suptitle('Coeficientes de Fourier con distintos valores de d')

# Plot for d=2
plt.subplot(3, 2, 1)
plt.stem(armo, modcoef_2, label='Modulo', linefmt='b-', markerfmt='bo', basefmt='b-')
plt.title('Modulo de los Coeficientes de Fourier (d=2)')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')
plt.legend()

plt.subplot(3, 2, 2)
plt.stem(armo, fascoef_2, label='Fase', linefmt='r-', markerfmt='ro', basefmt='r-')
plt.title('Fase de los Coeficientes de Fourier (d=2)')
plt.xlabel('Armonicos')
plt.ylabel('Fase')
plt.legend()

# Plot for d=4
plt.subplot(3, 2, 3)
plt.stem(armo, modcoef_4, label='Modulo', linefmt='b-', markerfmt='bo', basefmt='b-')
plt.title('Modulo de los Coeficientes de Fourier (d=4)')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')
plt.legend()

plt.subplot(3, 2, 4)
plt.stem(armo, fascoef_4, label='Fase', linefmt='r-', markerfmt='ro', basefmt='r-')
plt.title('Fase de los Coeficientes de Fourier (d=4)')
plt.xlabel('Armonicos')
plt.ylabel('Fase')
plt.legend()

# Plot for d=5
plt.subplot(3, 2, 5)
plt.stem(armo, modcoef_5, label='Modulo', linefmt='b-', markerfmt='bo', basefmt='b-')
plt.title('Modulo de los Coeficientes de Fourier (d=5)')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')
plt.legend()

plt.subplot(3, 2, 6)
plt.stem(armo, fascoef_5, label='Fase', linefmt='r-', markerfmt='ro', basefmt='r-')
plt.title('Fase de los Coeficientes de Fourier (d=5)')
plt.xlabel('Armonicos')
plt.ylabel('Fase')
plt.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# # Actividad 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

t = sp.symbols('t')
k = sp.symbols('k')
d = 2 # Ancho del escalon
T = sp.symbols('T')
f = 1/T
w = 2*sp.pi*f
# Calculo simbolicament ela expresion del coef. de la serie de Fourier compleja con f(t)=1
expk = sp.integrate(sp.exp(-1*sp.I*k*w*t), (t, -d/2, d/2))/T
sp.pprint(expk)

# Rango de los armonicos para los coeficientes
am = 25
armo = np.arange(-am, am+1, 1)
# Out:
# ⎧       2.0⋅ⅈ⋅π⋅k        -2.0⋅ⅈ⋅π⋅k
# ⎪       ─────────        ───────────
# ⎪           T                 T
# ⎪  ⅈ⋅T⋅ℯ            ⅈ⋅T⋅ℯ
# ⎨- ────────────── + ────────────────  for k > -∞ ∧ k < ∞ ∧ k ≠ 0
# ⎪      2⋅π⋅k             2⋅π⋅k
# ⎪
# ⎪                2.0                          otherwise
# ⎩
# ────────────────────────────────────────────────────────────────
#                                T

# %% [markdown]
# T = 8

# %%
# Evaluacion de la expresion de los coeficientes de Fourier con T = 8
expk_8 = expk.subs(T, 8)
coef_8 = [complex(expk_8.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier
modcoef_8 = np.abs(coef_8)
# Fase de los coef de fourier
fascoef_8 = np.angle(coef_8)

# Grafica del modulo y fase de los coeficientes
plt.figure(figsize=(12, 6))
plt.suptitle('Coeficientes de Fourier con T=8ms')
# Plot modulus of Fourier coefficients
plt.subplot(2, 1, 1)
plt.stem(armo, modcoef_8)
plt.title('Modulo de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

# Plot phase of Fourier coefficients
plt.subplot(2, 1, 2)
plt.stem(armo, fascoef_8)
plt.title('Fase de los Coeficientes de Fourier')
plt.xlabel('Armonicos')

plt.tight_layout()
plt.show()

# %% [markdown]
# T = 12

# %%
# Evaluacion de la expresion de los coeficientes de Fourier con T = 12
expk_12 = expk.subs(T, 12)
coef_12 = [complex(expk_12.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier
modcoef_12 = np.abs(coef_12)
# Fase de los coef de fourier
fascoef_12 = np.angle(coef_12)

# Grafica del modulo y fase de los coeficientes
plt.figure(figsize=(12, 6))
plt.suptitle('Coeficientes de Fourier con T=12ms')
# Plot modulus of Fourier coefficients
plt.subplot(2, 1, 1)
plt.stem(armo, modcoef_12)
plt.title('Modulo de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

# Plot phase of Fourier coefficients
plt.subplot(2, 1, 2)
plt.stem(armo, fascoef_12)
plt.title('Fase de los Coeficientes de Fourier')
plt.xlabel('Armonicos')

plt.tight_layout()
plt.show()

# %% [markdown]
# T = 18

# %%
# Evaluacion de la expresion de los coeficientes de Fourier con T = 18
expk_18 = expk.subs(T, 18)
coef_18 = [complex(expk_18.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier
modcoef_18 = np.abs(coef_18)
# Fase de los coef de fourier
fascoef_18 = np.angle(coef_18)

# Grafica del modulo y fase de los coeficientes
plt.figure(figsize=(12, 6))
plt.suptitle('Coeficientes de Fourier con T=18ms')
# Plot modulus of Fourier coefficients
plt.subplot(2, 1, 1)
plt.stem(armo, modcoef_18)
plt.title('Modulo de los Coeficientes de Fourier')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')

# Plot phase of Fourier coefficients
plt.subplot(2, 1, 2)
plt.stem(armo, fascoef_18)
plt.title('Fase de los Coeficientes de Fourier')
plt.xlabel('Armonicos')

plt.tight_layout()
plt.show()

# %%
# Subplot grande comparando los 3 graficos con distintos valores de T = [8, 12, 18] con d=2 fijo
plt.figure(figsize=(18, 12))
plt.suptitle('Coeficientes de Fourier con distintos valores de T')

# Plot for T=8
plt.subplot(3, 2, 1)
plt.stem(armo, modcoef_8, label='Modulo', linefmt='b-', markerfmt='bo', basefmt='b-')
plt.title('Modulo de los Coeficientes de Fourier (T=8)')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')
plt.legend()

plt.subplot(3, 2, 2)
plt.stem(armo, fascoef_8, label='Fase', linefmt='r-', markerfmt='ro', basefmt='r-')
plt.title('Fase de los Coeficientes de Fourier (T=8)')
plt.xlabel('Armonicos')
plt.ylabel('Fase')
plt.legend()

# Plot for T=12
plt.subplot(3, 2, 3)
plt.stem(armo, modcoef_12, label='Modulo', linefmt='b-', markerfmt='bo', basefmt='b-')
plt.title('Modulo de los Coeficientes de Fourier (T=12)')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')
plt.legend()

plt.subplot(3, 2, 4)
plt.stem(armo, fascoef_12, label='Fase', linefmt='r-', markerfmt='ro', basefmt='r-')
plt.title('Fase de los Coeficientes de Fourier (T=12)')
plt.xlabel('Armonicos')
plt.ylabel('Fase')
plt.legend()

# Plot for T=18
plt.subplot(3, 2, 5)
plt.stem(armo, modcoef_18, label='Modulo', linefmt='b-', markerfmt='bo', basefmt='b-')
plt.title('Modulo de los Coeficientes de Fourier (T=18)')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')
plt.legend()

plt.subplot(3, 2, 6)
plt.stem(armo, fascoef_18, label='Fase', linefmt='r-', markerfmt='ro', basefmt='r-')
plt.title('Fase de los Coeficientes de Fourier (T=18)')
plt.xlabel('Armonicos')
plt.ylabel('Fase')
plt.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()

# %% [markdown]
# # Actividad 4
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt
import sympy as sp

t = sp.symbols('t')
k = sp.symbols('k')
T = 20
f = 1/T
A = 1
w = 2*sp.pi*f

expk1 = sp.integrate((t*2*A/T)*sp.exp(-1*sp.I*k*w*t), (t, -T/2, T/2))/T
sp.pprint(expk1)

am = 25
armo = np.arange(-am, am+1, 1)
# Out:
# ⎧                            -1.0⋅ⅈ⋅π⋅k                            1.0⋅ⅈ⋅π⋅k   ↪
# ⎪  1.0⋅(-10.0⋅ⅈ⋅π⋅k - 10.0)⋅ℯ             1.0⋅(10.0⋅ⅈ⋅π⋅k - 10.0)⋅ℯ            ↪
# ⎪- ──────────────────────────────────── + ──────────────────────────────────   ↪
# ⎨                  2  2                                  2  2                  ↪
# ⎪                 π ⋅k                                  π ⋅k                   ↪
# ⎪                                                                              ↪
# ⎩                                     0                                        ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                    20                          ↪
#
# ↪
# ↪
# ↪ for k > -∞ ∧ k < ∞ ∧ k ≠ 0
# ↪
# ↪
# ↪
# ↪         otherwise
# ↪ ──────────────────────────
# ↪

# %%
# Definir la función por partes
f_t = sp.Piecewise(
    (-t, (t >= -T/2) & (t < -T/4)),
    (t, (t >= -T/4) & (t <= T/4)),
    (-t, (t > T/4) & (t <= T/2))
)

# Calcular la expresión de los coeficientes de Fourier
expk2 = sp.integrate(f_t * sp.exp(-1*sp.I*k*w*t), (t, -T/2, T/2)) / T
sp.pprint(expk2)
# Out:
# ⎧                            1.0⋅ⅈ⋅π⋅k                              -0.5⋅ⅈ⋅π⋅k ↪
# ⎪1.0⋅(-100.0⋅ⅈ⋅π⋅k + 100.0)⋅ℯ            1.0⋅(-50.0⋅ⅈ⋅π⋅k - 100.0)⋅ℯ           ↪
# ⎪───────────────────────────────────── - ───────────────────────────────────── ↪
# ⎨                 2  2                                    2  2                 ↪
# ⎪                π ⋅k                                    π ⋅k                  ↪
# ⎪                                                                              ↪
# ⎩                                                                              ↪
# ────────────────────────────────────────────────────────────────────────────── ↪
#                                                                                ↪
#
# ↪                               0.5⋅ⅈ⋅π⋅k                             0.5⋅ⅈ⋅π⋅ ↪
# ↪    1.0⋅(-50.0⋅ⅈ⋅π⋅k + 100.0)⋅ℯ            1.0⋅(50.0⋅ⅈ⋅π⋅k - 100.0)⋅ℯ         ↪
# ↪  - ──────────────────────────────────── + ────────────────────────────────── ↪
# ...

# %%
# Evaluacion de la expresion de los coeficientes de Fourier
coef1 = [complex(expk1.subs(k, i).evalf()) for i in armo]
coef2 = [complex(expk2.subs(k, i).evalf()) for i in armo]
# Modulo de los coef de fourier
modcoef1 = np.abs(coef1)
modcoef2 = np.abs(coef2)
# Fase de los coef de fourier
fascoef1 = np.angle(coef1)
fascoef2 = np.angle(coef2)

# %%
# Grafica del modulo y fase de los coeficientes para coef1 y coef2
plt.figure(figsize=(18, 12))

# Plot modulus of Fourier coefficients for coef1
plt.subplot(2, 2, 1)
plt.stem(armo, modcoef1, label='Modulo', linefmt='b-', markerfmt='bo', basefmt='b-')
plt.title('Modulo de los Coeficientes de Fourier (f(t)=t)')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')
plt.legend()

# Plot modulus of Fourier coefficients for coef2
plt.subplot(2, 2, 2)
plt.stem(armo, modcoef2, label='Modulo', linefmt='b-', markerfmt='bo', basefmt='b-')
plt.title('Modulo de los Coeficientes de Fourier (f(t) Serrucho)')
plt.xlabel('Armonicos')
plt.ylabel('Modulo')
plt.legend()

# Plot phase of Fourier coefficients for coef1
plt.subplot(2, 2, 3)
plt.stem(armo, fascoef1, label='Fase', linefmt='r-', markerfmt='ro', basefmt='r-')
plt.title('Fase de los Coeficientes de Fourier (f(t)=t)')
plt.xlabel('Armonicos')
plt.ylabel('Fase')
plt.legend()

# Plot phase of Fourier coefficients for coef2
plt.subplot(2, 2, 4)
plt.stem(armo, fascoef2, label='Fase', linefmt='r-', markerfmt='ro', basefmt='r-')
plt.title('Fase de los Coeficientes de Fourier (f(t) Serrucho)')
plt.xlabel('Armonicos')
plt.ylabel('Fase')
plt.legend()

plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.show()
